# %%
#data types in python
a = 10
b = 2.41
c = 'Adwaith'
d = [1,2,3,'ADWAITH',5]
e = (1,2,3,"adwaith",6)
f = {'adwaith':'yoo sup', 'reg no.':2462308}
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# 10
# 2.41
# Adwaith
# [1, 2, 3, 'ADWAITH', 5]
# (1, 2, 3, 'adwaith', 6)
# {'adwaith': 'yoo sup', 'reg no.': 2462308}

# %%
#input and output
name = input("enter your name :")
age = int(input("enter your age:"))
print("Your name is :",name)
print("Your age is:",age)
# Out:
# Your name is : Adwaith
# Your age is: 19

# %%
#operators in python

#arithmetic
a = 10
b = 2
print(" + sum",a+b)
print(" - difference:",a-b)
print(" / quotient :",a/b)
print(" '%' remainder :",a%b)

#relational
print("a>b",a>b)
print("a==b",a==b)
print("a<=b",a<=b)
print("a!=b",a!=b)

#logical
# Out:
#  + sum 12
#  - difference: 8
#  / quotient : 5.0
#  '%' remainder : 0
# a>b True
# a==b False
# a<=b False
# a!=b True
