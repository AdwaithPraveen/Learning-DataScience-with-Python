# %%
    # Strings
# '' or "" for one line 
# """ """ for multiple lines

s = "WelcomeToPython"
print("1:4",s[0:4])
print("3:",s[3:])
print(":3",s[:3])
print("::-1 reversing", s[::-1])

#editing characters
s = "adwaith"


s.title()
print(s)
# Out:
# 1:4 Welc
# 3: comeToPython
# :3 Wel
# ::-1 reversing nohtyPoTemocleW
# adwaith

# %%
i = '*'
def fact(x):
    if x == 0:
        return 1
# Out:
# *
# **
# ***
# ****
